# %%
import matplotlib.pyplot as plt
import numpy as np


MY = 1
DY = 1

IO = 2
LS = 4
CP = 6

# make dat a
x = [-8,-6.3,-6,-1,0,1,6,6.3,8]
y = [-0.2,-0.2,-1.25,-1,0,1,1.25,0.2,0.2]

# plot
fig, ax = plt.subplots()
ax.plot(x, y)

ax.set(xlabel='D/DY', ylabel='M/MY',
       title='Non-linear (FEMA) Skeleton Curve')
ax.grid()

plt.show()

# %%
MY = 1
DY = 0.0002660664

IO = 0.003/DY
LS = 0.012/DY
CP = 0.015/DY

print(IO)
print(LS)
print(CP)

# make data
x = [-8,-6.3,-6,-1,0,1,6,6.3,8]
y = [-0.2,-0.2,-1.25,-1,0,1,1.25,0.2,0.2]

# plot
fig, ax = plt.subplots()
ax.plot(x, y)

ax.set(xlabel='D/DY', ylabel='M/MY',
       title='Non-linear (FEMA) Skeleton Curve')
ax.grid()

plt.show()
# Out:
# 11.275380882366207
# 45.10152352946483
# 56.37690441183103

# %%
alpha = 0.05
MY = 1
DY = 6

a = 0.025
b = 0.05
c = 0.20
IO

IO = 0.010
LS = 0.025
CP = 0.05

AX = 0
BX = 1
CX = 1 + a
DX = CX + (CX*0.05)
EX = 1 + b


x = [AX,BX,CX,DX,EX]
y = [0,1,2]
