# %%
data = '''
REBAR-BEAM    ; Modify Beam Rebar Data
; iSEC, iSUBSEC, SBARNAME, DT, DB, CRACK, iDEFLEC, SIDEBAR, iSIDENUM, STIRNAME, SKINNAME, bSAMETOPBOT, bSAMEIMJ, bSAMELAYER ; line 1
; iTIARR, iTIRB1, iTIRB2, TINAME1, TINAME2, iBIARR, iBIRB1, iBIRB2, BINAME1, BINAME2, ISPACE, iISRBN, nISkin ; line 2
; iTMARR, iTMRB1, iTMRB2, TMNAME1, TMNAME2, iBMARR, iBMRB1, iBMRB2, BMNAME1, BMNAME2, MSPACE, iMSRBN, nMSkin ; line 3
; iTJARR, iTJRB1, iTJRB2, TJNAME1, TJNAME2, iBJARR, iBJRB1, iBJRB2, BJNAME1, BJNAME2, JSPACE, iJSRBN, nJSkin ; line 4
    2,    1, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 3, #8, #8,   0, 4, 2, #8, #8,   0.1, 4, 0
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.15, 4, 0
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 0
    2,    2, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 2, #8, #8,   0, 6, 2, #8, #8,   0.1, 4, 0
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.15, 4, 0
       0, 4, 2, #8, #8,   0, 4, 2, #8, #8,   0.1, 4, 0
    2,    3, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 4, 0
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 0
    2,    4, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
    2,    5, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 2, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 2, 0
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 2, 0
    2,    6, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 2, #8, #8,   0, 3, 0, #8, #8,   0.1, 2, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 2, 0
       0, 4, 2, #8, #8,   0, 3, 0, #8, #8,   0.1, 2, 0
    2,    7, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
    2,    8, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 4, 0
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 0
    2,    9, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
    2,   10, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
    2,   11, #5, 0.07, 0.07, 0, 0, , 0, , #5, YES, YES, YES
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 4
       0, 5, 0, #8, #8,   0, 4, 0, #8, #8,   0.15, 4, 4
       0, 5, 2, #8, #8,   0, 3, 0, #8, #8,   0.1, 4, 4
    2,   12, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
    2,   13, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
    2,   14, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 0
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.15, 4, 0
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 0
    2,   15, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 2, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 2, 0
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 2, 0
    2,   16, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
    2,   17, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
       0, 3, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 3, 0
       0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 3, 0
    2,   18, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
       0, 5, 5, #8, #8,   0, 5, 0, #8, #8,   0.1, 2, 0
       0, 5, 0, #8, #8,   0, 3, 0, #8, #8,   0.15, 2, 0
       0, 3, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 2, 2
    2,   19, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 1, #8, #8,   1, 4, 0, #8, #8,   0.114, 2, 0
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.314, 2, 0
       2, 5, 1, #8, #8,   1, 4, 0, #8, #8,   0.112, 2, 0
    2,   20, #4, 0.07, 0.07, 0, 1, #4, 7, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.15, 2, 7
       1, 3, 0, #8, #8,   1, 2, 0, #8, #8,   0.224, 2, 7
       1, 4, 0, #8, #8,   1, 3, 0, #8, #8,   0.15, 2, 7
    2,   21, #4, 0.07, 0.07, 0, 1, #4, 19, , #4, YES, YES, YES
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   1e-06, 2, 19
       2, 5, 3, #8, #8,   1, 3, 0, #8, #8,   1e-06, 2, 19
       2, 5, 5, #8, #8,   1, 5, 0, #8, #8,   1e-06, 2, 19
    2,   22, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 4, #8, #8,   1, 5, 0, #8, #8,   0.096, 2, 0
       1, 3, 0, #8, #8,   1, 5, 0, #8, #8,   0.314, 2, 0
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.105, 2, 0
    2,   23, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 5, 0, #8, #8,   0.078, 2, 0
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.194, 2, 0
       2, 5, 1, #8, #8,   1, 5, 0, #8, #8,   0.088, 2, 0
    2,   24, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.092, 2, 0
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.314, 2, 0
       2, 5, 1, #8, #8,   1, 3, 0, #8, #8,   0.103, 2, 0
    2,   25, #4, 0.07, 0.07, 0, 1, #4, 15, , #4, YES, YES, YES
       1, 3, 0, #8, #8,   1, 4, 0, #8, #8,   1e-06, 2, 15
       1, 3, 0, #8, #8,   1, 4, 0, #8, #8,   1e-06, 2, 15
       2, 5, 5, #8, #8,   1, 5, 0, #8, #8,   1e-06, 2, 15
    2,   26, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.144, 2, 0
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.314, 2, 0
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.145, 2, 0
    2,   27, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.143, 2, 0
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.314, 2, 0
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.144, 2, 0
    2,   28, #4, 0.07, 0.07, 0, 1, #4, 13, , #4, YES, YES, YES
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   1e-06, 2, 13
       1, 5, 0, #8, #8,   1, 3, 0, #8, #8,   1e-06, 2, 13
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   1e-06, 2, 13
    2,   29, #4, 0.07, 0.07, 0, 1, #4, 8, , #4, YES, YES, YES
       1, 5, 0, #8, #8,   2, 5, 1, #8, #8,   0.081, 2, 8
       1, 4, 0, #8, #8,   1, 3, 0, #8, #8,   0.133, 2, 8
       2, 5, 3, #8, #8,   1, 4, 0, #8, #8,   0.07, 2, 8
    2,   30, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.11, 2, 0
       1, 3, 0, #8, #8,   1, 4, 0, #8, #8,   0.314, 2, 0
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.109, 2, 0
    2,   31, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 3, #8, #8,   1, 5, 0, #8, #8,   0.069, 2, 0
       1, 4, 0, #8, #8,   1, 3, 0, #8, #8,   0.149, 2, 0
       2, 5, 1, #8, #8,   2, 5, 1, #8, #8,   0.078, 2, 0
    2,   32, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 3, #8, #8,   1, 4, 0, #8, #8,   0.078, 2, 0
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.314, 2, 0
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.09, 2, 0
    2,   33, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 3, #8, #8,   2, 5, 1, #8, #8,   0.05, 2, 0
       1, 4, 0, #8, #8,   1, 4, 0, #8, #8,   0.053, 2, 0
       2, 5, 3, #8, #8,   2, 5, 2, #8, #8,   0.052, 2, 0
    2,   34, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.108, 2, 0
       1, 3, 0, #8, #8,   1, 4, 0, #8, #8,   0.314, 2, 0
       2, 5, 3, #8, #8,   1, 4, 0, #8, #8,   0.103, 2, 0
    2,   35, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 5, #8, #8,   1, 5, 0, #8, #8,   0.101, 2, 0
       1, 3, 0, #8, #8,   1, 5, 0, #8, #8,   0.314, 2, 0
       2, 5, 4, #8, #8,   1, 5, 0, #8, #8,   0.102, 2, 0
    2,   36, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 4, #8, #8,   2, 5, 2, #8, #8,   0.051, 2, 0
       1, 4, 0, #8, #8,   1, 4, 0, #8, #8,   0.08, 2, 0
       2, 5, 3, #8, #8,   2, 5, 3, #8, #8,   0.056, 2, 0
    2,   37, #4, 0.07, 0.07, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.107, 2, 8
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.206, 2, 8
       2, 5, 3, #8, #8,   1, 4, 0, #8, #8,   0.106, 2, 8
    2,   38, #4, 0.07, 0.07, 0, 1, #4, 8, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 4, 0, #8, #8,   0.15, 2, 8
       1, 2, 0, #8, #8,   1, 5, 0, #8, #8,   0.224, 2, 8
       1, 2, 0, #8, #8,   1, 4, 0, #8, #8,   0.15, 2, 8
    2,   39, #4, 0.07, 0.07, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 5, 0, #8, #8,   1, 3, 0, #8, #8,   0.15, 2, 0
       1, 2, 0, #8, #8,   1, 3, 0, #8, #8,   0.314, 2, 0
       1, 5, 0, #8, #8,   1, 3, 0, #8, #8,   0.15, 2, 0
    2,   40, #4, 0.07, 0.07, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 3, #8, #8,   2, 5, 2, #8, #8,   0.048, 2, 8
       1, 4, 0, #8, #8,   1, 4, 0, #8, #8,   0.051, 2, 8
       2, 5, 3, #8, #8,   2, 5, 3, #8, #8,   0.05, 2, 8
    3,    1, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 3, 1, #8, #8,   1, 2, 0, #8, #8,   0.08, 2, 0
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.168, 2, 0
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 0
    3,    2, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 3, 0, #8, #8,   0.084, 2, 0
       1, 3, 0, #8, #8,   1, 2, 0, #8, #8,   0.168, 2, 0
       2, 3, 3, #8, #8,   1, 3, 0, #8, #8,   0.077, 2, 0
    3,    3, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 3, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 0
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.168, 2, 0
       1, 3, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 0
    3,    4, #4, 0.0635, 0.0635, 0, 1, #4, 3, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 3
       1, 2, 0, #8, #8,   1, 3, 0, #8, #8,   0.118, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 3
    3,    5, #4, 0.0635, 0.0635, 0, 1, #4, 11, , #4, YES, YES, YES
       2, 3, 2, #8, #8,   1, 3, 0, #8, #8,   1e-06, 2, 11
       1, 3, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 11
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 11
    3,    6, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 0
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.168, 2, 0
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 0
    3,    7, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 3, 0, #8, #8,   2, 3, 3, #8, #8,   0.077, 2, 0
       1, 3, 0, #8, #8,   2, 3, 3, #8, #8,   0.155, 2, 0
       1, 3, 0, #8, #8,   2, 3, 3, #8, #8,   0.077, 2, 0
    3,    8, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 3, 0, #8, #8,   0.084, 2, 0
       1, 2, 0, #8, #8,   2, 3, 2, #8, #8,   0.158, 2, 0
       1, 2, 0, #8, #8,   1, 3, 0, #8, #8,   0.084, 2, 0
    3,    9, #4, 0.0635, 0.0635, 0, 1, #4, 9, , #4, YES, YES, YES
       2, 3, 3, #8, #8,   1, 3, 0, #8, #8,   1e-06, 2, 9
       2, 3, 1, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 9
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 9
    3,   10, #4, 0.0635, 0.0635, 0, 1, #4, 3, , #4, YES, YES, YES
       1, 3, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.118, 2, 3
       1, 3, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 3
    3,   11, #4, 0.0635, 0.0635, 0, 1, #4, 10, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 10
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 10
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 10
    3,   12, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 3, 1, #8, #8,   1, 3, 0, #8, #8,   0.077, 2, 0
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 0
       2, 3, 1, #8, #8,   1, 3, 0, #8, #8,   0.08, 2, 0
    3,   13, #4, 0.0635, 0.0635, 0, 1, #4, 3, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.118, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 3
    3,   14, #4, 0.0635, 0.0635, 0, 1, #4, 7, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 7
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 7
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 7
    3,   15, #4, 0.0635, 0.0635, 0, 1, #4, 4, , #4, YES, YES, YES
       1, 3, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 4
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.118, 2, 4
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 4
    3,   16, #4, 0.0635, 0.0635, 0, 1, #4, 8, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 8
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 8
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 8
    3,   17, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   2, 3, 1, #8, #8,   0.08, 2, 0
       1, 3, 0, #8, #8,   2, 3, 3, #8, #8,   0.155, 2, 0
       1, 2, 0, #8, #8,   1, 3, 0, #8, #8,   0.084, 2, 0
    3,   18, #4, 0.0635, 0.0635, 0, 1, #4, 5, , #4, YES, YES, YES
       2, 3, 1, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 5
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 5
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 5
    3,   19, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   2, 3, 1, #8, #8,   0.08, 2, 0
       1, 3, 0, #8, #8,   2, 3, 3, #8, #8,   0.155, 2, 0
       1, 2, 0, #8, #8,   2, 3, 1, #8, #8,   0.08, 2, 0
    3,   20, #4, 0.0635, 0.0635, 0, 1, #4, 3, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.118, 2, 3
       2, 3, 2, #8, #8,   1, 3, 0, #8, #8,   0.079, 2, 3
    3,   21, #4, 0.0635, 0.0635, 0, 1, #4, 3, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.118, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 3
    3,   22, #4, 0.0635, 0.0635, 0, 1, #4, 3, , #4, YES, YES, YES
       1, 3, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.118, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 3
    3,   23, #4, 0.0635, 0.0635, 0, 1, #4, 4, , #4, YES, YES, YES
       2, 3, 1, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 4
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 4
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 4
    3,   24, #4, 0.0635, 0.0635, 0, 1, #4, 4, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 4
       1, 2, 0, #8, #8,   1, 3, 0, #8, #8,   0.118, 2, 4
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 4
    3,   25, #4, 0.0635, 0.0635, 0, 1, #4, 3, , #4, YES, YES, YES
       2, 3, 1, #8, #8,   1, 2, 0, #8, #8,   0.08, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.118, 2, 3
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 3
    3,   26, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   2, 3, 2, #8, #8,   0.079, 2, 0
       1, 3, 0, #8, #8,   2, 3, 3, #8, #8,   0.155, 2, 0
       1, 2, 0, #8, #8,   2, 3, 2, #8, #8,   0.079, 2, 0
    3,   27, #4, 0.0635, 0.0635, 0, 1, #4, 9, , #4, YES, YES, YES
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 9
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 9
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   1e-06, 2, 9
    5,    1, #4, 0.0635, 0.0635, 0, 1, #4, 4, , #4, YES, YES, YES
       1, 4, 0, #8, #8,   1, 3, 0, #8, #8,   0.084, 2, 4
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.143, 2, 4
       1, 4, 0, #8, #8,   1, 3, 0, #8, #8,   0.084, 2, 4
    5,    2, #4, 0.0635, 0.0635, 0, 1, #4, 4, , #4, YES, YES, YES
       1, 4, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 4
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.143, 2, 4
       1, 4, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 4
    5,    3, #4, 0.0635, 0.0635, 0, 1, #4, 0, , #4, YES, YES, YES
       1, 4, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 0
       1, 2, 0, #8, #8,   1, 2, 0, #8, #8,   0.168, 2, 0
       1, 4, 0, #8, #8,   1, 2, 0, #8, #8,   0.084, 2, 0
    6,    1, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       1, 5, 0, #8, #8,   1, 4, 0, #8, #8,   0.127, 2, 8
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.216, 2, 8
       1, 5, 0, #8, #8,   1, 4, 0, #8, #8,   0.128, 2, 8
    6,    2, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   2, 5, 1, #8, #8,   0.081, 2, 8
       1, 4, 0, #8, #8,   1, 4, 0, #8, #8,   0.207, 2, 8
       2, 5, 1, #8, #8,   1, 5, 0, #8, #8,   0.084, 2, 8
    6,    3, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       1, 5, 0, #8, #8,   1, 3, 0, #8, #8,   0.146, 2, 8
       1, 2, 0, #8, #8,   1, 3, 0, #8, #8,   0.216, 2, 8
       1, 5, 0, #8, #8,   1, 3, 0, #8, #8,   0.146, 2, 8
    6,    4, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 5, 0, #8, #8,   0.078, 2, 8
       1, 3, 0, #8, #8,   1, 4, 0, #8, #8,   0.207, 2, 8
       2, 5, 1, #8, #8,   1, 5, 0, #8, #8,   0.082, 2, 8
    6,    5, #4, 0.065, 0.065, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 4, #8, #8,   1, 5, 0, #8, #8,   0.093, 2, 0
       1, 3, 0, #8, #8,   1, 4, 0, #8, #8,   0.292, 2, 0
       2, 5, 3, #8, #8,   1, 4, 0, #8, #8,   0.093, 2, 0
    6,    6, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.115, 2, 8
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.216, 2, 8
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.116, 2, 8
    6,    7, #4, 0.065, 0.065, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.108, 2, 0
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.292, 2, 0
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.108, 2, 0
    6,    8, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.13, 2, 8
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.216, 2, 8
       2, 5, 1, #8, #8,   1, 3, 0, #8, #8,   0.139, 2, 8
    6,    9, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.088, 2, 8
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.216, 2, 8
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.094, 2, 8
    6,   10, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 1, #8, #8,   1, 3, 0, #8, #8,   0.103, 2, 8
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.216, 2, 8
       2, 5, 1, #8, #8,   1, 3, 0, #8, #8,   0.1, 2, 8
    6,   11, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 3, #8, #8,   1, 4, 0, #8, #8,   0.117, 2, 8
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.216, 2, 8
       2, 5, 3, #8, #8,   1, 4, 0, #8, #8,   0.118, 2, 8
    6,   12, #4, 0.065, 0.065, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.124, 2, 0
       1, 3, 0, #8, #8,   1, 3, 0, #8, #8,   0.292, 2, 0
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.125, 2, 0
    6,   13, #4, 0.065, 0.065, 0, 1, #4, 0, , #4, YES, YES, YES
       2, 5, 1, #8, #8,   1, 3, 0, #8, #8,   0.144, 2, 0
       1, 2, 0, #8, #8,   1, 3, 0, #8, #8,   0.292, 2, 0
       2, 5, 1, #8, #8,   1, 3, 0, #8, #8,   0.144, 2, 0
    6,   14, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 2, #8, #8,   1, 4, 0, #8, #8,   0.103, 2, 8
       1, 3, 0, #8, #8,   1, 4, 0, #8, #8,   0.216, 2, 8
       2, 5, 3, #8, #8,   1, 4, 0, #8, #8,   0.107, 2, 8
    6,   15, #4, 0.065, 0.065, 0, 1, #4, 8, , #4, YES, YES, YES
       2, 5, 5, #8, #8,   1, 5, 0, #8, #8,   0.103, 2, 8
       1, 3, 0, #8, #8,   1, 5, 0, #8, #8,   0.216, 2, 8
       2, 5, 4, #8, #8,   1, 5, 0, #8, #8,   0.1, 2, 8
    6,   16, #5, 0.065, 0.065, 0, 0, , 0, , #5, YES, YES, YES
       0, 4, 4, #8, #8,   0, 4, 2, #8, #8,   0.1, 4, 3
       0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 3
       0, 4, 2, #8, #8,   0, 4, 2, #8, #8,   0.1, 4, 3
''' 

print(data)
# Out:
# REBAR-BEAM    ; Modify Beam Rebar Data
# ; iSEC, iSUBSEC, SBARNAME, DT, DB, CRACK, iDEFLEC, SIDEBAR, iSIDENUM, STIRNAME, SKINNAME, bSAMETOPBOT, bSAMEIMJ, bSAMELAYER ; line 1
# ; iTIARR, iTIRB1, iTIRB2, TINAME1, TINAME2, iBIARR, iBIRB1, iBIRB2, BINAME1, BINAME2, ISPACE, iISRBN, nISkin ; line 2
# ; iTMARR, iTMRB1, iTMRB2, TMNAME1, TMNAME2, iBMARR, iBMRB1, iBMRB2, BMNAME1, BMNAME2, MSPACE, iMSRBN, nMSkin ; line 3
# ; iTJARR, iTJRB1, iTJRB2, TJNAME1, TJNAME2, iBJARR, iBJRB1, iBJRB2, BJNAME1, BJNAME2, JSPACE, iJSRBN, nJSkin ; line 4
#     2,    1, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
#        0, 4, 3, #8, #8,   0, 4, 2, #8, #8,   0.1, 4, 0
#        0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.15, 4, 0
#        0, 4, 2, #8, #8,   0, 4, 0, #8, #8,   0.1, 4, 0
#     2,    2, #4, 0.07, 0.07, 0, 0, , 0, , #4, YES, YES, YES
#        0, 4, 2, #8, #8,   0, 6, 2, #8, #8,   0.1, 4, 0
#        0, 4, 0, #8, #8,   0, 4, 0, #8, #8,   0.15, 4, 0
# ...
